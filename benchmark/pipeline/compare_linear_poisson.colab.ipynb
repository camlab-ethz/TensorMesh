# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install gmsh  
# !pip install meshio 
# !pip install matplotlib 
# !pip install tqdm 
# !pip install scikit-fem 
# !pip install seaborn 
# !pip install petsc petsc4py
# !pip install cupy-cuda11x
# !pip install fenics 
# !pip install pyvista  
# !pip install toml 
# !pip install scipy

# %%
from compare_linear_poisson import plot_comparison


chara_lengths = [0.2, 0.1, 0.05, 0.01, 0.005, 0.004]
fig = plot_comparison(
    element_type="tri",
    chara_lengths=chara_lengths,
    n_times=5,
    csv_path="compare_poisson_linear_2d.csv",
    device=f"cuda:0"
)
fig.savefig("compare_linear_poisson_2d.png")

# %%
from compare_linear_poisson import plot_comparison

chara_lengths = [0.2, 0.1, 0.05, 0.04, 0.03]
fig = plot_comparison(
    element_type="tri",
    chara_lengths=chara_lengths,
    n_times=5,
    csv_path="compare_poisson_linear_3d.csv",
    device=f"cuda:0"
)
fig.savefig("compare_linear_poisson_3d.png")
